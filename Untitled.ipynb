# %% [markdown]
# Flow of the Code
#
# - We will take the picture anfd using matplotlib take out the Region Of Interest(For now the time which we want to extract)
# - We will crop the region of interest and feed it to the pytesseract to get the output

# %% [markdown]
# Tested
#
# - Already tested with the cropped image manually and the results are coming correct
#
# Challenges
#
# - Using Matplotlib we are getting the ROI coordinates correctly, however while plotting it the region is not showing.
# - Croping code is not running, the notebook gets stuck on  it

# %% [markdown]
# Possible Errors
#
# - Some of the functions don't run on the Jupyter Notebook eg cv2.imshow().
# - We can test it on the vs code

# %% [markdown]
# Source
#
# For Finding ROI
# - https://medium.com/@khandelwalprateek01/how-to-select-roi-in-jupyter-notebook-309fe5185a54
# - https://matplotlib.org/3.1.1/users/event_handling.html

# %%
import matplotlib.pyplot as plt
import IPython.display as Disp
from ipywidgets import widgets
import numpy as np
import cv2

# %%
class bbox_select():
    # %matplotlib notebook 


    def __init__(self,im):
        self.im = im
        self.selected_points = []
        self.fig,ax = plt.subplots()
        self.img = ax.imshow(self.im.copy())
        self.ka = self.fig.canvas.mpl_connect('button_press_event', self.onclick)
        disconnect_button = widgets.Button(description="Disconnect mpl")
        Disp.display(disconnect_button)
        disconnect_button.on_click(self.disconnect_mpl)


        
    def poly_img(self,img,pts):
        pts = np.array(pts, np.int32)
        pts = pts.reshape((-1,1,2))
        cv2.polylines(img,[pts],True,(np.random.randint(0,255),np.random.randint(0,255),np.random.randint(0,255)),7)
        return img

    def onclick(self, event):
    #display(str(event))
        self.selected_points.append([event.xdata,event.ydata])
        if len(self.selected_points)>1:
            self.fig
            self.img.set_data(self.poly_img(self.im.copy(),self.selected_points))
    def disconnect_mpl(self,_):
        self.fig.canvas.mpl_disconnect(self.ka)

# %%
im = plt.imread('test1.png')

# %%
bs = bbox_select(im)
# Out:
# <img src="data:image/png;base64,..." width="890">
# Button(description='Disconnect mpl', style=ButtonStyle())

# %%
bs.selected_points
# Out:
# [[1562.2667728768347, 1475.0618435546166],
#  [1575.3845691798433, 1619.3576028877083],
#  [954.4755441707819, 1614.9850041200389],
#  [971.9659392414596, 1479.434442322286]]

# %% [markdown]
# [[1562.2667728768347, 1475.0618435546166],
#  [1575.3845691798433, 1619.3576028877083],
#  [954.4755441707819, 1614.9850041200389],
#  [971.9659392414596, 1479.434442322286]]

# %%
arr = np.array([bs.selected_points],'int')
print(arr)
mask = cv2.fillPoly(np.zeros(im.shape,np.uint8),arr,[1,1,1])
op = np.multiply(im,mask)
plt.imshow(op)
# Out:
# [[[1562 1475]
#   [1575 1619]
#   [ 954 1614]
#   [ 971 1479]]]
# <img src="data:image/png;base64,..." width="640">

# %%
# import cv2 as cv
# import numpy as np

# img = cv.imread('test1.png')
# # cv.imshow('Original', img)

# blank = np.zeros(img.shape[:2], dtype='uint8')

# center_coordinates = (144, 233)

# radius = 10

# mask = cv.circle(blank, center_coordinates, radius, 255, -1)

# masked = cv.bitwise_and(img, img, mask=mask)
# # cv.imshow('Output', masked)

# cv.waitKey(0)

# %% [markdown]
# [[[1562 1475]
#   [1575 1619]
#   [ 954 1614]
#   [ 971 1479]]]

# %%
import cv2
img = cv2.imread("test1.png")
crop_img = img[1475:1619, 954:1575]
# cv2.imshow("cropped", crop_img)
cv2.waitKey(0)

# %%
image = cv2.imread('test2.png')

# %%
x,y,w,h = cv2.selectROI(image)

# %%
print(x,y,w,h)

# %%
cv2.destroyAllWindows()

# %%
# extractedInformation = pytesseract.image_to_string(Image.open('test2.png'))
# print(extractedInformation)
